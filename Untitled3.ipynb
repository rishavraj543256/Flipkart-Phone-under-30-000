# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup as soup
import numpy as np

# %%
url='https://www.flipkart.com/search?q=best+smartphone+under+30000&as=on&as-show=on&otracker=AS_Query_OrganicAutoSuggest_4_15_na_na_na&otracker1=AS_Query_OrganicAutoSuggest_4_15_na_na_na&as-pos=4&as-type=RECENT&suggestionId=best+smartphone+under+30000&requestId=abce313f-823d-4926-bd00-b125b8e0b6f2&as-backfill=on&page=1'
response=requests.get(url)
response
# Out:
# <Response [200]>

# %%
data=soup(response.text,'html.parser')
data
# Out:
# <!DOCTYPE html>
# ...

# %%
div_data=data.findAll('div',{'class':'_2kHMtA'})

# %%
title=[]
star=[]
rating=[]
reviews=[]
sp=[]
mrp=[]
discount=[]
ram=[]
rom=[]
for i in div_data:
        tit=i.find('div',{'class':'_4rR01T'}).text
        title.append(tit)
        try:
            st=i.find('div',{'class':'_3LWZlK'}).text
            star.append(st)
        except:
            star.append('None')
        try:
            rat=i.find('span',{'class':'_2_R_DZ'}).text.split('&')[0].strip()
            rating.append(rat)
        except:
            tating.append('None')
        try:
            rev=i.find('span',{'class':'_2_R_DZ'}).text.split('&')[1].strip()
            reviews.append(rev)
        except:
            reviews.append('None')
        try:
            cost=i.find('div',{'class':'_30jeq3 _1_WHN1'}).text
            sp.append(cost)
        except:
            sp.append('None')
        try:    
            mp=i.find('div',{'class':'_3I9_wc _27UcVY'}).text
            mrp.append(mp)
        except:
            mrp.append('None')
        try:
            off=i.find('div',{'class':'_3Ay6Sb'}).text
            discount.append(off)
        except:
            discount.append('None')
        try:
            ul=i.findAll('li',{'class':'rgWa7D'})[0].text.split('|')[0]
            ram.append(ul)
        except:
            ram.append('None')
        try:
            ul=i.findAll('li',{'class':'rgWa7D'})[0].text.split('|')[1]
            rom.append(ul)
        except:
            rom.append('None')

# %%
final=pd.DataFrame()
for j in range(1,42):
    url='https://www.flipkart.com/search?q=best+smartphone+under+30000&as=on&as-show=on&otracker=AS_Query_OrganicAutoSuggest_4_15_na_na_na&otracker1=AS_Query_OrganicAutoSuggest_4_15_na_na_na&as-pos=4&as-type=RECENT&suggestionId=best+smartphone+under+30000&requestId=abce313f-823d-4926-bd00-b125b8e0b6f2&as-backfill=on&page={}'.format(j)
    response=requests.get(url)
    data=soup(response.text,'html.parser')
    div_data=data.findAll('div',{'class':'_2kHMtA'})
    title=[]
    star=[]
    rating=[]
    reviews=[]
    sp=[]
    mrp=[]
    discount=[]
    ram=[]
    rom=[]
    for i in div_data:
            tit=i.find('div',{'class':'_4rR01T'}).text
            title.append(tit)
            try:
                st=i.find('div',{'class':'_3LWZlK'}).text
                star.append(st)
            except:
                star.append('None')
            try:
                rat=i.find('span',{'class':'_2_R_DZ'}).text.split('&')[0].strip()
                rating.append(rat)
            except:
                rating.append('None')
            try:
                rev=i.find('span',{'class':'_2_R_DZ'}).text.split('&')[1].strip()
                reviews.append(rev)
            except:
                reviews.append('None')
            try:
                cost=i.find('div',{'class':'_30jeq3 _1_WHN1'}).text
                sp.append(cost)
            except:
                sp.append('None')
            try:    
                mp=i.find('div',{'class':'_3I9_wc _27UcVY'}).text
                mrp.append(mp)
            except:
                mrp.append('None')
            try:
                off=i.find('div',{'class':'_3Ay6Sb'}).text
                discount.append(off)
            except:
                discount.append('None')
            try:
                ul=i.findAll('li',{'class':'rgWa7D'})[0].text.split('|')[0]
                ram.append(ul)
            except:
                ram.append('None')
            try:
                ul=i.findAll('li',{'class':'rgWa7D'})[0].text.split('|')[1]
                rom.append(ul)
            except:
                rom.append('None')
    dict={"Title":title,'Star':star,"Rating":rating,'Review':reviews,'Selling Price':sp,'Market Price':mp,'Discount':discount,'RAM':ram,'ROM':rom}
    df=pd.DataFrame(dict)
    final=final.append(df)
# Out:
# C:\Users\risha\AppData\Local\Temp\ipykernel_7304\2192674461.py:61: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final=final.append(df)
# C:\Users\risha\AppData\Local\Temp\ipykernel_7304\2192674461.py:61: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final=final.append(df)
# C:\Users\risha\AppData\Local\Temp\ipykernel_7304\2192674461.py:61: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final=final.append(df)
# C:\Users\risha\AppData\Local\Temp\ipykernel_7304\2192674461.py:61: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final=final.append(df)
# ...

# %%
final
# Out:
#                                                 Title Star          Rating  \
# 0               OPPO Reno8 5G (Shimmer Black, 128 GB)  4.3  29,597 Ratings
# 1                OPPO Reno8 5G (Shimmer Gold, 128 GB)  4.3  29,597 Ratings
# 2              MOTOROLA Edge 30 (Meteor Grey, 128 GB)  4.1   3,007 Ratings
# 3   Xiaomi 11i Hypercharge 5G (Pacific Pearl, 128 GB)  4.2   6,130 Ratings
# 4             MOTOROLA Edge 30 (Aurora Green, 128 GB)  4.1   3,007 Ratings
# ..                                                ...  ...             ...
# 19             MOTOROLA G51 5G (Bright Silver, 64 GB)  4.1  15,490 Ratings
# 20             REDMI Note 10S (Deep Sea Blue, 128 GB)  4.2   7,028 Ratings
# 21                    vivo Y21 (Diamond Glow, 128 GB)  4.3  14,249 Ratings
# 22                 REDMI Note 9 (Pebble Grey, 128 GB)  4.3   6,540 Ratings
# 23        APPLE iPhone 13 Mini ((PRODUCT)RED, 512 GB)  4.5   2,930 Ratings
#
#            Review Selling Price Market Price Discount         RAM  \
# ...

# %%
#final.to_csv('Phone Under 30000.csv',index=False)

# %%
final.shape
# Out:
# (960, 9)

# %%
final['Review']=final['Review'].str.strip('Reviews')

# %%
final=final.rename(columns={'Review':'Reviews'})

# %%
final['Rating']=final['Rating'].str.strip('Ratings')

# %%
final=final.rename(columns={'Rating':'Ratings'})

# %%
final['ROM']=final['ROM'].str.replace('ROM'," ")

# %%
final['RAM']=final['RAM'].str.replace('RAM'," ")

# %%
final['RAM']=final['RAM'].str.replace('RO'," ").replace('ROM'," ")

# %%
final['ROM'].tail(300)
# Out:
# 12      64 GB
# 13      64 GB
# 14       64 GB
# 15      128 GB
# 16          None
#          ...
# 19      64 GB
# 20     128 GB
# 21     128 GB
# 22     128 GB
# 23          None
# Name: ROM, Length: 300, dtype: object

# %%
final
# Out:
#                                                 Title Star  Ratings Reviews  \
# 0               OPPO Reno8 5G (Shimmer Black, 128 GB)  4.3  29,597   3,902
# 1                OPPO Reno8 5G (Shimmer Gold, 128 GB)  4.3  29,597   3,902
# 2              MOTOROLA Edge 30 (Meteor Grey, 128 GB)  4.1   3,007     459
# 3   Xiaomi 11i Hypercharge 5G (Pacific Pearl, 128 GB)  4.2   6,130     683
# 4             MOTOROLA Edge 30 (Aurora Green, 128 GB)  4.1   3,007     459
# ..                                                ...  ...      ...     ...
# 19             MOTOROLA G51 5G (Bright Silver, 64 GB)  4.1  15,490   1,935
# 20             REDMI Note 10S (Deep Sea Blue, 128 GB)  4.2   7,028     653
# 21                    vivo Y21 (Diamond Glow, 128 GB)  4.3  14,249   1,078
# 22                 REDMI Note 9 (Pebble Grey, 128 GB)  4.3   6,540     437
# 23        APPLE iPhone 13 Mini ((PRODUCT)RED, 512 GB)  4.5   2,930     251
#
#    Selling Price Market Price Discount        RAM         ROM
# ...

# %%
final.to_csv('Phone Under 30000.csv',index=False)
