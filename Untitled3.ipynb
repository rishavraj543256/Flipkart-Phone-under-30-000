# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup as soup
import numpy as np

# %%
url='https://www.flipkart.com/search?q=best+smartphone+under+30000&as=on&as-show=on&otracker=AS_Query_OrganicAutoSuggest_4_15_na_na_na&otracker1=AS_Query_OrganicAutoSuggest_4_15_na_na_na&as-pos=4&as-type=RECENT&suggestionId=best+smartphone+under+30000&requestId=abce313f-823d-4926-bd00-b125b8e0b6f2&as-backfill=on&page=1'
response=requests.get(url)
response

# %%
data=soup(response.text,'html.parser')
data

# %%
div_data=data.findAll('div',{'class':'_2kHMtA'})

# %%
title=[]
star=[]
rating=[]
reviews=[]
sp=[]
mrp=[]
discount=[]
ram=[]
rom=[]
for i in div_data:
        tit=i.find('div',{'class':'_4rR01T'}).text
        title.append(tit)
        try:
            st=i.find('div',{'class':'_3LWZlK'}).text
            star.append(st)
        except:
            star.append('No star')
        try:
            rat=i.find('span',{'class':'_2_R_DZ'}).text.split('&')[0].strip()
            rating.append(rat)
        except:
            tating.append('No Rating')
        try:
            rev=i.find('span',{'class':'_2_R_DZ'}).text.split('&')[1].strip()
            reviews.append(rev)
        except:
            reviews.append('No Reviews')
        try:
            cost=i.find('div',{'class':'_30jeq3 _1_WHN1'}).text
            sp.append(cost)
        except:
            sp.append('None')
        try:    
            mp=i.find('div',{'class':'_3I9_wc _27UcVY'}).text
            mrp.append(mp)
        except:
            mrp.append('None')
        try:
            off=i.find('div',{'class':'_3Ay6Sb'}).text
            discount.append(off)
        except:
            discount.append('None')
        try:
            ul=i.findAll('li',{'class':'rgWa7D'})[0].text.split('|')[0]
            ram.append(ul)
        except:
            ram.append('No RAM')
        try:
            ul=i.findAll('li',{'class':'rgWa7D'})[0].text.split('|')[1]
            rom.append(ul)
        except:
            rom.append('No ROM')

# %%
final=pd.DataFrame()
for j in range(1,42):
    url='https://www.flipkart.com/search?q=best+smartphone+under+30000&as=on&as-show=on&otracker=AS_Query_OrganicAutoSuggest_4_15_na_na_na&otracker1=AS_Query_OrganicAutoSuggest_4_15_na_na_na&as-pos=4&as-type=RECENT&suggestionId=best+smartphone+under+30000&requestId=abce313f-823d-4926-bd00-b125b8e0b6f2&as-backfill=on&page={}'.format(j)
    response=requests.get(url)
    data=soup(response.text,'html.parser')
    div_data=data.findAll('div',{'class':'_2kHMtA'})
    title=[]
    star=[]
    rating=[]
    reviews=[]
    sp=[]
    mrp=[]
    discount=[]
    ram=[]
    rom=[]
    for i in div_data:
            tit=i.find('div',{'class':'_4rR01T'}).text
            title.append(tit)
            try:
                st=i.find('div',{'class':'_3LWZlK'}).text
                star.append(st)
            except:
                star.append('No star')
            try:
                rat=i.find('span',{'class':'_2_R_DZ'}).text.split('&')[0].strip()
                rating.append(rat)
            except:
                rating.append('No Rating')
            try:
                rev=i.find('span',{'class':'_2_R_DZ'}).text.split('&')[1].strip()
                reviews.append(rev)
            except:
                reviews.append('No Reviews')
            try:
                cost=i.find('div',{'class':'_30jeq3 _1_WHN1'}).text
                sp.append(cost)
            except:
                sp.append('None')
            try:    
                mp=i.find('div',{'class':'_3I9_wc _27UcVY'}).text
                mrp.append(mp)
            except:
                mrp.append('None')
            try:
                off=i.find('div',{'class':'_3Ay6Sb'}).text
                discount.append(off)
            except:
                discount.append('None')
            try:
                ul=i.findAll('li',{'class':'rgWa7D'})[0].text.split('|')[0]
                ram.append(ul)
            except:
                ram.append('No RAM')
            try:
                ul=i.findAll('li',{'class':'rgWa7D'})[0].text.split('|')[1]
                rom.append(ul)
            except:
                rom.append('No ROM')
    dict={"Title":title,'Star':star,"Rating":rating,'Review':reviews,'Selling Price':sp,'Market Price':mp,'Discount':discount,'RAM':ram,'ROM':rom}
    df=pd.DataFrame(dict)
    final=final.append(df)
# Out:
# C:\Users\risha\AppData\Local\Temp\ipykernel_7516\1158911921.py:61: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final=final.append(df)
# C:\Users\risha\AppData\Local\Temp\ipykernel_7516\1158911921.py:61: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final=final.append(df)
# C:\Users\risha\AppData\Local\Temp\ipykernel_7516\1158911921.py:61: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final=final.append(df)
# C:\Users\risha\AppData\Local\Temp\ipykernel_7516\1158911921.py:61: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final=final.append(df)
# C:\Users\risha\AppData\Local\Temp\ipykernel_7516\1158911921.py:61: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final=final.append(df)
# C:\Users\risha\AppData\Local\Temp\ipykernel_7516\1158911921.py:61: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final=final.append(df)
# C:\Users\risha\AppData\Local\Temp\ipykernel_7516\1158911921.py:61: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final=final.append(df)
# C:\Users\risha\AppData\Local\Temp\ipykernel_7516\1158911921.py:61: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final=final.append(df)
# C:\Users\risha\AppData\Local\Temp\ipykernel_7516\1158911921.py:61: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final=final.append(df)
# C:\Users\risha\AppData\Local\Temp\ipykernel_7516\1158911921.py:61: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final=final.append(df)
# C:\Users\risha\AppData\Local\Temp\ipykernel_7516\1158911921.py:61: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final=final.append(df)
# C:\Users\risha\AppData\Local\Temp\ipykernel_7516\1158911921.py:61: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final=final.append(df)
# C:\Users\risha\AppData\Local\Temp\ipykernel_7516\1158911921.py:61: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final=final.append(df)
# C:\Users\risha\AppData\Local\Temp\ipykernel_7516\1158911921.py:61: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final=final.append(df)
# C:\Users\risha\AppData\Local\Temp\ipykernel_7516\1158911921.py:61: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final=final.append(df)
# C:\Users\risha\AppData\Local\Temp\ipykernel_7516\1158911921.py:61: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final=final.append(df)
# C:\Users\risha\AppData\Local\Temp\ipykernel_7516\1158911921.py:61: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final=final.append(df)
# C:\Users\risha\AppData\Local\Temp\ipykernel_7516\1158911921.py:61: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final=final.append(df)
# C:\Users\risha\AppData\Local\Temp\ipykernel_7516\1158911921.py:61: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final=final.append(df)
# C:\Users\risha\AppData\Local\Temp\ipykernel_7516\1158911921.py:61: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final=final.append(df)
# C:\Users\risha\AppData\Local\Temp\ipykernel_7516\1158911921.py:61: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final=final.append(df)
# C:\Users\risha\AppData\Local\Temp\ipykernel_7516\1158911921.py:61: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final=final.append(df)
# C:\Users\risha\AppData\Local\Temp\ipykernel_7516\1158911921.py:61: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final=final.append(df)
# C:\Users\risha\AppData\Local\Temp\ipykernel_7516\1158911921.py:61: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final=final.append(df)
# C:\Users\risha\AppData\Local\Temp\ipykernel_7516\1158911921.py:61: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final=final.append(df)
# C:\Users\risha\AppData\Local\Temp\ipykernel_7516\1158911921.py:61: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final=final.append(df)
# C:\Users\risha\AppData\Local\Temp\ipykernel_7516\1158911921.py:61: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final=final.append(df)
# C:\Users\risha\AppData\Local\Temp\ipykernel_7516\1158911921.py:61: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final=final.append(df)
# C:\Users\risha\AppData\Local\Temp\ipykernel_7516\1158911921.py:61: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final=final.append(df)
# C:\Users\risha\AppData\Local\Temp\ipykernel_7516\1158911921.py:61: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final=final.append(df)
# C:\Users\risha\AppData\Local\Temp\ipykernel_7516\1158911921.py:61: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final=final.append(df)
# C:\Users\risha\AppData\Local\Temp\ipykernel_7516\1158911921.py:61: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final=final.append(df)
# C:\Users\risha\AppData\Local\Temp\ipykernel_7516\1158911921.py:61: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final=final.append(df)
# C:\Users\risha\AppData\Local\Temp\ipykernel_7516\1158911921.py:61: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final=final.append(df)
# C:\Users\risha\AppData\Local\Temp\ipykernel_7516\1158911921.py:61: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final=final.append(df)
# C:\Users\risha\AppData\Local\Temp\ipykernel_7516\1158911921.py:61: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final=final.append(df)
# C:\Users\risha\AppData\Local\Temp\ipykernel_7516\1158911921.py:61: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final=final.append(df)
# C:\Users\risha\AppData\Local\Temp\ipykernel_7516\1158911921.py:61: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final=final.append(df)
# C:\Users\risha\AppData\Local\Temp\ipykernel_7516\1158911921.py:61: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final=final.append(df)

# %%
final
# Out:
#                                           Title Star            Rating  \
# 0            IQOO 7 5G (Monster Orange, 128 GB)  4.4       139 Ratings
# 1        Xiaomi 11Lite NE (Vinyl Black, 128 GB)  4.2     1,390 Ratings
# 2          vivo V23e 5G (Midnight Blue, 128 GB)  4.2     1,557 Ratings
# 3       MOTOROLA Edge 30 (Aurora Green, 128 GB)  4.1     2,879 Ratings
# 4    SAMSUNG Galaxy A32 (Awesome Black, 128 GB)  4.1       249 Ratings
# ..                                          ...  ...               ...
# 19       POCO M2 Pro (Green and Greener, 64 GB)  4.4  3,49,545 Ratings
# 20            POCO M3 Pro 5G (Cool Blue, 64 GB)  4.3    62,329 Ratings
# 21  REDMI NOTE 10 LITE (Champagne Gold, 128 GB)  4.3     2,057 Ratings
# 22              OPPO A54 (Crystal Black, 64 GB)  4.4    10,611 Ratings
# 23               OPPO A55 (Starry Black, 64 GB)  4.2       648 Ratings
#
#             Review Selling Price Market Price Discount        RAM  \
# 0       28 Reviews       ₹24,990      ₹31,999  28% off  8 GB RAM
# 1      150 Reviews       ₹23,780      ₹31,999     None  8 GB RAM
# 2      149 Reviews       ₹22,969      ₹31,999   8% off  8 GB RAM
# 3      445 Reviews       ₹29,999      ₹31,999  14% off  8 GB RAM
# 4       26 Reviews       ₹18,989      ₹31,999  15% off  8 GB RAM
# ..             ...           ...          ...      ...        ...
# 19  33,233 Reviews       ₹14,999      ₹18,990  16% off  6 GB RAM
# 20   4,833 Reviews       ₹14,499      ₹18,990   9% off  4 GB RAM
# 21     164 Reviews       ₹13,990      ₹18,990  17% off  4 GB RAM
# 22     656 Reviews       ₹13,990      ₹18,990   6% off  4 GB RAM
# 23      62 Reviews       ₹14,490      ₹18,990  23% off  4 GB RAM
#
#              ROM
# 0     128 GB ROM
# 1    128 GB ROM
# 2    128 GB ROM
# 3     128 GB ROM
# 4    128 GB ROM
# ..           ...
# 19    64 GB ROM
# 20    64 GB ROM
# 21    128 GB ROM
# 22    64 GB ROM
# 23    64 GB ROM
#
# [984 rows x 9 columns]

# %%
final.to_csv('Phone Under 30000.csv',index=False)
